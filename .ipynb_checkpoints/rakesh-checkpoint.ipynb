# %%
import requests

url = requests.get("https://www.rgukt.ac.in/")
url.status_code
content = url.text
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>
# <html lang="en" class="ie8">
#    <![endif]-->
#    <!--[if IE 9]>
#    <html lang="en" class="ie9">
#       <![endif]-->
#       <!--[if !IE]><!-->
#       <html lang="en">
#          <!--<![endif]-->
#          <head>
#             <meta name="google-site-verification" content="ZCuRaGPu0iTMFKv96XUQ11RpjRBasDy_8u0gawGAA2U" />
#             <title>Rajiv Gandhi University of Knowledge Technologies Basar</title>
#             <!-- Meta -->
#             <meta charset="utf-8">
#             <meta http-equiv="X-UA-Compatible" content="IE=edge">
#             <meta name="viewport" content="width=device-width, initial-scale=1.0">
#             <meta name="keywords" content="RGUKT, RGUKT Hub, Basar, Info Hub, IIIT Basar, RGUKT IIIT Basar, IIIT Hub, IIIT,  Rajiv Gandhi University of Knowledge Technologies">
# ...

# %%
splitted = content.split("\n")
for i in splitted:
    if i.__contains__("<a") :
        anc = i[i.index("=")+2:]
        print(anc)
# Out:
# /"><img id="logo" src="assets/images/rgulogo2.png" alt="RGUKT Basar Logo"></a>
# http://www.telangana.gov.in" target="_blank">
# http://www.telangana.gov.in" target="_blank">
# active nav-item"><a href="index.html">Home</a></li>
# dropdown-toggle" data-toggle="dropdown" data-hover="dropdown" data-delay="0" data-close-others="false" href="index.html#">ABOUT US <i class="fa fa-angle-down"></i></a>
# about-introduction.html">About RGUKT</a></li>
# vision-mission.html">Vision and Mission</a></li>
# gc.html">Governing Council</a></li>
# administration-section.html">Administration</a></li>
# cd.html">Communication Directory</a></li>-->
# dropdown-toggle" data-toggle="dropdown" data-hover="dropdown" data-delay="0" data-close-others="false" href="#">ADMINISTRATION <i class="fa fa-angle-down"></i></a>
# vc.html">Vice Chancellor</a></li>
# director.html">Director</a></li-->
# gc.html">Governing Council</a></li-->
# administration-section.html">Administration</a></li>
# ...

# %%
import requests
import re

# URL of the website to scrape
url = "https://www.rgukt.ac.in/"  # Replace with your target website

# Send an HTTP GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    html_content = response.text

    # Regular expression to find all anchor tags and their href attributes
    anchor_tags = re.findall(r'<a\s+[^>]*href=["\'](.*?)["\']', html_content, re.IGNORECASE)

    # Print extracted links
    for link in anchor_tags:
        print(link)
else:
    print(f"Failed to fetch the page. Status code: {response.status_code}")
# Out:
# /
# http://www.telangana.gov.in
# http://www.telangana.gov.in
# index.html
# index.html#
# about-introduction.html
# vision-mission.html
# gc.html
# administration-section.html
# cd.html
# #
# vc.html
# director.html
# gc.html
# administration-section.html
# cd.html
# #
# academicprogrammes.html
# curricula.html
# academiccalender.html
# departments.html
# #
# examination.html
# #
# bio-sciences.html
# che.html
# chemistry.html
# ce.html
# cse.html
# eee.html
# ece.html
# hss.html
# mme.html
# maths.html
# me.html
# physics.html
# schoolmng.html
# #
# hostels.html
#
# counseling.html
# library/
# hospital.html
#
#
# shopping-complex.html
#
#
# #
# pla-internships.html
# placementprocedure.html
# pla-inftostu.html
# pla-inftocomp.html
# reachus.html
# contactus.html
# examination.html
# placement/index.html
# http://careers.rgukt.ac.in
# #
# alumni.html
# contactus.html
# assets/docs/RGUKTProvisionalist.pdf
# convocation2023.html
# convocation2023.html
# index.html#news-carousel
# ...

# %%
class A :
    # def __init__(self):
    #   self.__a = 1000
    def add(self,a,b):
        print(a+b)
        # print("Hello")
    def add(self,a,b,c=100):
        print(a+b+c)

obj = A()
obj.add(10,20)
# Out:
# 130

# %%
class A :
    def add(self,a,b):
        print(a,b)
    def add(self,a,b,c=100):
        print(a+b+c)
obj = A()
obj.add(10,20)
# Out:
# 130

# %%
s1 = "abcde"
s1.count("a")
# Out:
# 1
